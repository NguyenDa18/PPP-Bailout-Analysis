# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = "foia_150k_plus.csv"

df = pd.read_csv(filename, parse_dates=['DateApproved'])
df.drop(['NonProfit'], axis='columns', inplace=True)

# %%
df.head()
# Out:
#          LoanRange                           BusinessName  \
# 0  a $5-10 million  ARCTIC SLOPE NATIVE ASSOCIATION, LTD.
# 1  a $5-10 million                  CRUZ CONSTRUCTION INC
# 2  a $5-10 million                 I. C. E. SERVICES, INC
# 3  a $5-10 million             KATMAI HEALTH SERVICES LLC
# 4  a $5-10 million        MATANUSKA TELEPHONE ASSOCIATION
#
#                                   Address       City State      Zip  \
# 0                            7000 Uula St     BARROW    AK  99723.0
# 1            7000 East Palmer Wasilla Hwy     PALMER    AK  99645.0
# 2                           2606 C Street  ANCHORAGE    AK  99503.0
# 3  11001 O'MALLEY CENTRE DRIVE, SUITE 204  ANCHORAGE    AK  99515.0
# 4                      1740 S. CHUGACH ST     PALMER    AK  99645.0
#
#    NAICSCode                     BusinessType RaceEthnicity      Gender  \
# 0   813920.0          Non-Profit Organization    Unanswered  Unanswered
# ...

# %%
df['BusinessName'].isnull().sum()
# Out:
# 8

# %%
df.dropna(subset=['BusinessName'], inplace=True)

# %%
filtered = df[df['State'].str.contains('OR')]
filtered
# Out:
#                  LoanRange                                       BusinessName  \
# 492015     a $5-10 million                 ACME CONSTRUCTION SUPPLY CO., INC.
# 492016     a $5-10 million               CHARTER MECHANICAL CONTRACTORS, INC.
# 492017     a $5-10 million                         CHRISTENSON ELECTRIC, INC.
# 492018     a $5-10 million                               COLLINS PINE COMPANY
# 492019     a $5-10 million                   COLUMBIA STEEL CASTING CO., INC.
# ...                    ...                                                ...
# 501234  e $150,000-350,000                                         ZEVEZ CORP
# 501235  e $150,000-350,000                                          ZIM, INC.
# 501236  e $150,000-350,000  ZION EVANGELICAL LUTHERAN CHURCH, (U.A.C.) UNA...
# 501237  e $150,000-350,000                                         ZIWATT INC
# 501238  e $150,000-350,000                                           ZNE CORP
#
# ...

# %% [markdown]
# ## Kanye
# - Billionaires get million dollar loans

# %%
yeezy_bail = df[df['BusinessName'].str.contains('YEEZY')]
yeezy_bail
# Out:
#             LoanRange BusinessName                 Address      City State  \
# 29024  b $2-5 million    YEEZY LLC  6 CENTERPOINTE DR #700  LA PALMA    CA
#
#            Zip  NAICSCode                     BusinessType  \
# 29024  90623.0   448110.0  Limited  Liability Company(LLC)
#
#                    RaceEthnicity      Gender      Veteran  JobsRetained  \
# 29024  Black or African American  Male Owned  Non-Veteran         106.0
#
#       DateApproved              Lender       CD
# 29024   2020-04-13  City National Bank  CA - 38

# %% [markdown]
# ## Kushners
# - Notice that FL Kushner and Kushney Attorneys received loan and NO jobs were retained

# %%
kushner_bail = df[df['BusinessName'].str.contains('KUSHNER')]
kushner_bail
# Out:
#                    LoanRange  \
# 49433   d $350,000-1 million
# 169296    e $150,000-350,000
# 232992    e $150,000-350,000
# 267014  d $350,000-1 million
# 363022  d $350,000-1 million
# 386848        c $1-2 million
# 400844    e $150,000-350,000
# 447101    e $150,000-350,000
# 449343    e $150,000-350,000
#
#                                              BusinessName  \
# 49433       KUSHNER CARLSON, PROFESSIONAL LAW CORPORATION
# 169296                      KUSHNER AND KUSHNER ATTORNEYS
# 232992                  KUSHNER BECKER AND ASSOCIATES LTD
# 267014                              KUSHNER LAGRAIZE, LLC
# 363022                             KUSHNER AND KUSHNER PC
# 386848                JOSEPH KUSHNER HEBREW ACADEMY, INC.
# 400844                            KUSHNER DRAPERY MFG LLC
# 447101  HOLLWICH KUSHNER ARCHITECTURE D.P.C. DBA HWKN ...
# 449343       KUSHNER STUDIOS ARCHITECTURE &AMP; DESIGN PC
#
#                                            Address         City State  \
# ...
