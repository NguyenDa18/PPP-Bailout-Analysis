# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = "foia_up_to_150k_OR.csv"

df = pd.read_csv(filename, parse_dates=['DateApproved'])

# %%
# NonProfit column comes as NaN because all blank in csv
df.drop(['NonProfit'], axis='columns', inplace=True)

# %%
df.dropna(subset=['BusinessType'], inplace=True)

# %%
df
# Out:
#        LoanAmount         City State    Zip  NAICSCode  \
# 0       149995.00      GRESHAM    OR  97030   624120.0
# 1       149977.00     PORTLAND    OR  97232   236118.0
# 2       149962.50     PORTLAND    OR  97210   722511.0
# 3       149911.00    JEFFERSON    OR  97352   236115.0
# 4       149897.45         BEND    OR  97701   323111.0
# ...           ...          ...   ...    ...        ...
# 53546       22.00     TUALATIN    OR  97062   561499.0
# 53547        8.00     PORTLAND    OR  97209   812112.0
# 53548        7.00  LAKE OSWEGO    OR  97035   561990.0
# 53549        7.00  LAKE OSWEGO    OR  97034   813910.0
# 53550        5.00     PORTLAND    OR  97202   531210.0
#
#                           BusinessType RaceEthnicity        Gender  \
# 0                          Corporation    Unanswered    Unanswered
# 1      Limited  Liability Company(LLC)    Unanswered    Unanswered
# 2      Limited  Liability Company(LLC)    Unanswered    Unanswered
# ...

# %% [markdown]
# # Summary
# ---

# %% [markdown]
# ### Jobs Saved In Total

# %%
df['JobsRetained'].sum()
# Out:
# 239362.0

# %% [markdown]
# ### Business Types

# %%
df['BusinessType'].value_counts()
# Out:
# Limited  Liability Company(LLC)        18665
# Corporation                            12500
# Sole Proprietorship                     8654
# Subchapter S Corporation                8226
# Non-Profit Organization                 1875
# Independent Contractors                 1353
# Self-Employed Individuals               1178
# Partnership                              508
# Limited Liability Partnership            288
# Professional Association                 186
# Cooperative                               32
# Non-Profit Childcare Center               15
# Trust                                     12
# Joint Venture                              7
# Employee Stock Ownership Plan(ESOP)        2
# Tenant in Common                           1
# Name: BusinessType, dtype: int64
