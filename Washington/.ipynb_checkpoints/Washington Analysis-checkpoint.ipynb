# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = "foia_up_to_150k_WA.csv"

df = pd.read_csv(filename, parse_dates=['DateApproved'])

# %%
df
# Out:
#        LoanAmount            City State      Zip  NAICSCode  \
# 0        149992.0      BELLINGHAM    WA  98225.0        NaN
# 1        149980.0  SPOKANE VALLEY    WA  99216.0   621210.0
# 2        149975.0        KIRKLAND    WA  98033.0   339999.0
# 3        149950.0    PORT ORCHARD    WA  98367.0   238210.0
# 4        149922.0      BURLINGTON    WA  98233.0   999990.0
# ...           ...             ...   ...      ...        ...
# 85197         9.0        PUYALLUP    WA  98373.0   621340.0
# 85198         9.0         SPOKANE    WA  99217.0   453991.0
# 85199         2.0      NORTH BEND    WA  98045.0   541611.0
# 85200         2.0       SAMMAMISH    WA  98074.0   541213.0
# 85201         1.0         TUKWILA    WA  98188.0   314999.0
#
#                           BusinessType RaceEthnicity      Gender     Veteran  \
# 0             Subchapter S Corporation    Unanswered  Unanswered  Unanswered
# 1      Limited  Liability Company(LLC)    Unanswered  Unanswered  Unanswered
# ...

# %%
df['JobsRetained'].sum()
# Out:
# 351522.0

# %%
df['BusinessType'].value_counts()
# Out:
# Limited  Liability Company(LLC)        31621
# Corporation                            22624
# Sole Proprietorship                    12337
# Subchapter S Corporation               10791
# Non-Profit Organization                 2748
# Self-Employed Individuals               1937
# Independent Contractors                 1461
# Partnership                              719
# Limited Liability Partnership            403
# Professional Association                 366
# Cooperative                               51
# Non-Profit Childcare Center               38
# Joint Venture                             19
# Trust                                     11
# Employee Stock Ownership Plan(ESOP)        8
# Tenant in Common                           3
# Name: BusinessType, dtype: int64
